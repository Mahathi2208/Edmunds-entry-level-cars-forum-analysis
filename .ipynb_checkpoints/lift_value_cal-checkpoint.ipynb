# %%
import pandas as pd
import numpy as np
import itertools
import re
from functools import partial

# %%
comments = pd.read_csv('comments.csv').drop('Unnamed: 0', axis=1)
word_cnt = pd.read_csv('word_freq.csv').drop('Unnamed: 0', axis=1)
carbrands_models = pd.read_csv('carmodels_brands.csv')

# %%
# finding all the models for a car brand
carbrands_models['Brand'] = carbrands_models['Brand'].apply(lambda x: re.compile(r'[,.]').sub('', x))
carbrands_models['Brand'] = carbrands_models['Brand'].apply(lambda x: x.replace('hyundai', 'kia') \
                                                                      .replace('mercedes-benz', 'benz') \
                                                                      .replace('mercedes benz', 'benz') \
                                                                      .replace('hyndai kia', 'kia') \
                                                                      .replace('mercedes', 'benz') \
                                                                      .replace('toyata', 'toyota') \
                                                                      .replace('volkwagen', 'volkswagen'))
#getting all the unique brands 
car_brands = list(set(carbrands_models['Brand']))
car_brands = [re.compile(r'[,.]').sub('', i) for i in car_brands]
print("no of brands", len(car_brands))
wordfreq_dict = dict(word_cnt[['word', 'frequency']].values)
missing_brands = set(car_brands) - set(wordfreq_dict.keys())
print("missing brands:", missing_brands)
# Out:
# no of brands 29
# missing brands: set()

# %%
# %%time
# handling the replaced values by adding them as a model for a brand
handle_replace_dict = {'kia': ['hyundai', 'hyundai kia'], 'benz': ['mercedes-benz', 'mercedes benz', 'mercedes'],
                       'toyota' : ['toyata'], 'volkswagen': ['volkwagen']}
brand_models_map = carbrands_models.groupby(['Brand'])['Model'].unique().reset_index()
brand_models_map['Model'] = brand_models_map.apply(lambda row: list(set(list(row.Model) + list(handle_replace_dict[str(row.Brand)])))
                                                               if row.Brand in handle_replace_dict else list(set(row.Model)), axis=1)

brand_models_map = brand_models_map.set_index('Brand').to_dict()['Model']
brand_models_map
# Out:
# CPU times: total: 0 ns
# Wall time: 5.98 ms
# {'acura': ['mdx',
#   'legend',
#   'tsx',
#   'rsx',
#   'ilx',
#   'integra',
#   'rlx',
#   'vigor',
#   'rdx'],
#  'audi': ['quattro', 'a4', 'a5', 'a3', 'a8', 'q3', 'a7', 'a6', 'q5', 'q7'],
#  'benz': ['c-class',
#   'mercedes benz',
#   'e-class',
#   'benz',
#   's-class',
#   'mercedesbenz',
#   'mercedes-benz',
#   'cl-class',
#   'mercedes'],
#  'bmw': ['328i',
#   'm6',
#   '528i',
#   '330c',
#   'm5',
#   '3er',
#   '535i',
#   '640i',
#   '5er',
#   '128i',
#   'xdrive',
#   '335i',
#   '335d',
#   '3-series',
#   'bmwesque',
#   '5-series',
#   'bmws',
#   'm3',
#   '4-series',
#   '330ci',
#   'alpina',
#   '6-series'],
#  'buick': ['enclave',
#   'park avenue',
#   'encore',
#   'regal',
#   'buicks',
#   'lacrosse',
#   'century',
#   'la crosse'],
#  'cadillac': ['xts', 'escalade', 'srx'],
#  'car': ['cars'],
#  'chevrolet': ['aveo',
#   'caprice',
#   'impala',
#   'grand blazer',
#   'malibu',
#   'agile',
#   'tornado',
#   'equinox',
#   'malibus',
#   'lumina',
#   'montana',
#   'corvette',
#   'onix',
#   'optra',
#   'traverse',
#   'celta',
#   'tahoe',
#   'orlando',
#   'cavalier',
#   'volt',
#   'chevy',
#   'colorado',
#   'lova',
#   's-10',
#   'niva',
#   'silverado',
#   'spark',
#   'lacetti',
#   'lanos',
#   'uplander',
#   'tracker',
#   'tavera',
#   'captiva',
#   'trailblazer',
#   'cruze',
#   'camaro',
#   'cobalt',
#   'omega',
#   'express',
#   'n200',
#   'sonic',
#   'prisma',
#   'suburban',
#   'sail'],
#  'chrysler': ['cruiser',
#   'chrysler 300',
#   'chrysler 200',
#   'chryslers',
#   'lx',
#   '300m',
#   'town and country',
#   'sebring',
#   'pacifica'],
#  'dodge': ['viper',
#   'charger',
#   'stealth',
#   'caliber',
#   'journey',
#   'magnum',
#   'intrepid',
#   'durango',
#   'challenger',
#   'dart',
#   'avenger',
#   'ram'],
#  'ford': ['cmax',
#   'fiesta',
#   'focus',
#   'freestar',
#   'galaxy',
#   'expedition',
#   'fusionmilan',
#   'fusions',
#   'tourneo',
#   'kuga',
#   'fords',
#   'c-max',
#   'explorer',
#   'supervan',
#   'ecoline',
#   's-max',
#   'everest',
#   'f150',
#   'taurus',
#   'mustang',
#   'fusion',
#   'crownvictoria',
#   'f-150',
#   'escape'],
#  'honda': ['legend',
#   'zest',
#   'spike',
#   'insight',
#   'shuttle',
#   'cr-z',
#   'spirior',
#   'nbox',
#   'aria',
#   'n-wgn',
#   'crv',
#   'amaze',
#   'hobio',
#   'nsx',
#   'city',
#   'prelude',
#   'odyssey',
#   'n-box',
#   'n-one',
#   'freed',
#   'mobilio',
#   'odessey',
#   'ex-l',
#   'civic',
#   'inspire',
#   'exl',
#   'vezel',
#   '5dr',
#   'brio',
#   'vamos',
#   'fcx',
#   'stepwgn',
#   'accord',
#   'jazz',
#   'hondas',
#   'crider',
#   'jade',
#   'cr-v',
#   'crosstour',
#   'accords',
#   'stream',
#   'ridgeline',
#   'pilot',
#   'acty'],
#  'infiniti': ['fx35',
#   'q70',
#   'qx60',
#   'g37',
#   'qx50',
#   'q60',
#   'g25',
#   '6mt',
#   'qx70',
#   'q50'],
#  'kia': ['ix20',
#   'hyundais',
#   'k900',
#   'i45',
#   'genesis',
#   'santamo',
#   'elantra',
#   'atoz',
#   'i30',
#   'veracruz',
#   'sonatas',
#   'pony',
#   'verna',
#   'lavity',
#   'i40',
#   'hyundaikia',
#   'grandeur',
#   'xcent',
#   'santro',
#   'forte',
#   'kias',
#   'xg',
#   'matrix',
#   'veloster',
#   'scoupe',
#   'sonata',
#   'excel,',
#   'tuscani',
#   'stellar',
#   'i10',
#   'dynasty',
#   'optima',
#   'koup',
#   'centennial',
#   'getz',
#   'atos',
#   'excel.',
#   'sorento',
#   'equus',
#   'i20',
#   'santa',
#   'hyundai kia',
#   'click',
#   'avante',
#   'tiburon',
#   'sedona',
#   'azera',
#   'cadenza',
#   'hyundai',
#   'lantra',
#   'accent'],
#  'lincoln': ['zephyr',
#   'mkc',
#   'mkx',
#   'mkz',
#   'town car',
#   'navigator',
#   'mkt',
#   'mks'],
#  'mazda': ['cx9',
#   'demio',
#   'cx-7',
#   'atenza',
#   'mazda5',
#   'cx5',
#   'mazdas',
#   'familia',
#   'cx-5',
#   'scrum',
#   'mazda2',
#   'mazda6',
#   'axela',
#   'carol',
#   'bt-50',
#   'rx8',
#   'az-wagon',
#   'mazda8',
#   'mx-5',
#   'rx-8',
#   'cx-9',
#   'mazda6i',
#   '6i',
#   'mazda3',
#   'premacy',
#   'az-offroad',
#   'biante',
#   'bongo',
#   'mazda6s'],
#  'mercury': ['mercury', 'milan'],
#  'mitsubishi': ['lancer', 'galant'],
#  'nissan': ['altima',
#   'juke',
#   'quest.',
#   '370z',
#   'quest,',
#   'cube',
#   'pathfinder',
#   'titan',
#   'leaf',
#   'sentra',
#   'frontier',
#   'nissans',
#   'maxima',
#   'altimas',
#   'versa',
#   'xterra',
#   'rogue',
#   'armada',
#   'murano'],
#  'pontiac': ['g4',
#   'grand prix',
#   'gxp',
#   'g8',
#   'wave',
#   'grand am',
#   'sunfire',
#   'gto',
#   'g5',
#   'torpedo',
#   'vibe',
#   'aztek',
#   'streamliner',
#   'g3',
#   'g6'],
#  'problem': ['problems'],
#  'saturn': ['aura'],
#  'seat': ['seats'],
#  'sedan': ['sedans'],
#  'subaru': ['tribeca',
#   'r2',
#   'exiga',
#   'liberty',
#   'pleo',
#   'impreza',
#   'sambar',
#   'outback',
#   'brz',
#   'dex',
#   'forester',
#   'crosstrek',
#   'wrx',
#   'impreza xv',
#   'r1',
#   'lancaster',
#   'legacy',
#   'stella',
#   'gravel',
#   'grand wagon',
#   'outback sport'],
#  'suzuki': ['xl7',
#   'ignis',
#   'equator',
#   'escudo',
#   'splash',
#   'fronte',
#   'wagon r',
#   'mr wagon',
#   'esteem',
#   'x-90',
#   'cervo',
#   'every landy',
#   'lapin',
#   'mighty boy',
#   'swift',
#   'solio',
#   'palette',
#   'aerio',
#   'jimny',
#   'cultus',
#   'kizashi',
#   'landy',
#   'liana',
#   'ertiga',
#   'geo metro',
#   'apv',
#   'sx4',
#   'cappuccino',
#   'forsa'],
#  'toyota': ['sai',
#   'aygo',
#   'verso',
#   'toyoace',
#   'toyotas',
#   'venza',
#   'sequoia',
#   'vanguard',
#   'fortuner',
#   'fiedler',
#   'venture',
#   'mark x',
#   'cami',
#   'fj cruiser',
#   'camrys',
#   'echo',
#   'reiz',
#   'stallion',
#   'tacoma',
#   'highlander',
#   'etios',
#   'allion',
#   'liteace',
#   'comfort',
#   'townace',
#   'noah',
#   'bb',
#   'platz',
#   'vios',
#   'condor',
#   'majesta',
#   'tundra',
#   'kijang',
#   'carri',
#   'isis',
#   'innova',
#   'corolla/sprinter',
#   'sienta',
#   'estima',
#   'miniace',
#   'sienna',
#   'vitz',
#   'belta',
#   'tiara',
#   'avanza',
#   'solara',
#   'qualis',
#   'premio',
#   'land cruiser',
#   'rav4',
#   'tarago',
#   'vienta',
#   'porte',
#   'hiclass',
#   'auris',
#   'matrix',
#   'hilux',
#   'passo',
#   'zelas',
#   'kluger',
#   'iq',
#   'granvia',
#   'avalon',
#   'succeed',
#   'nadia',
#   'camrybest',
#   'urban cruiser',
#   'sofia',
#   'raum',
#   'voxy',
#   'yaris',
#   'coaster',
#   'kingdom',
#   'alphard',
#   'ist',
#   'tamaraw',
#   'zio',
#   'avensis',
#   'camry',
#   'century',
#   'picnic',
#   'hiace',
#   'aurion',
#   'probox',
#   'scepter',
#   'ractis',
#   'prius',
#   '4runner',
#   'dyna',
#   'corolla',
#   'sparky',
#   'axio',
#   'toyata',
#   'hilux surf',
#   'rumion'],
#  'volkswagen': ['rabbit',
#   'jetta',
#   'volkwagen',
#   'gti',
#   'touraeg',
#   'passats',
#   'vw',
#   'sportwagen',
#   'golf',
#   'vws',
#   'beetle',
#   'eos',
#   'tiguan',
#   'passat'],
#  'volvo': ['v60', 'c70', 's60', 'xc60', 'xc90', 'xc70', 's80']}

# %%
# for brand in missing_brands:
#     try:       
#         for i in brand.split(' '):
#             print([word for word in list(wordfreq_dict.keys()) if i in str(word)])
#         for i in brand.split('-'):
#             print([word for word in list(wordfreq_dict.keys()) if i in str(word)])
#     except Exception as e:
#         print(brand)
# # considering hyndai kia as kia, mercedes-benz as benz , mercedes benz as benz,toyata as toyota
# mis_brand_handle = {'hyndai kia': 'kia', 'mercedes-benz': 'benz', 'mercedes benz': 'benz', 'toyata': 'toyota'}
# car_brands = [mis_brand_handle[b] if b in list(mis_brand_handle.keys()) else b for b in car_brands]
# mis_brand_handle_t = {'kia': ['hyndai kia'], 'benz': ['mercedes-benz', 'mercedes benz' ], 'toyota': ['toyota']}

# %%
car_brands = list(set(carbrands_models['Brand']) - set(['car']))
car_brands
# Out:
# ['subaru',
#  'cadillac',
#  'bmw',
#  'mercury',
#  'lincoln',
#  'volkswagen',
#  'toyota',
#  'infiniti',
#  'pontiac',
#  'chevrolet',
#  'volvo',
#  'audi',
#  'suzuki',
#  'honda',
#  'nissan',
#  'acura',
#  'ford',
#  'benz',
#  'seat',
#  'mazda',
#  'buick',
#  'problem',
#  'mitsubishi',
#  'sedan',
#  'kia',
#  'dodge',
#  'chrysler',
#  'saturn']

# %%
def get_lift_value(a_brand, b_brand, comments, brand_models_map):
    """
    returns the lift value for given two brands 
    """
    p_a_b = 0
    p_a =0
    p_b =0
    for comment in comments:
        p_a_tmp =0
        p_b_tmp =0
        if type(comment) == float:
            continue
        else:
            word_set = [re.sub(r'[^\w]', ' ', word).strip().lower() for word in comment.split()]
            final_word_set = word_set.copy()
            final_word_set = [list(final_word_set) + [re.sub(r'[^\w]', ' ', w).strip().lower() 
                                                      for w in word.split()] for word in word_set if " " in word]
            final_word_set = set(list(itertools.chain.from_iterable(final_word_set)))
            if set(final_word_set).intersection(set([a_brand] + brand_models_map[a_brand])):
                p_a_tmp+=1
            if set(final_word_set).intersection(set([b_brand] + brand_models_map[b_brand])):
                p_b_tmp+=1
            if sum([1 for w in final_word_set if a_brand in w or w in a_brand]):
                p_a_tmp+=1
            if sum([1 for w in final_word_set if b_brand in w or w in b_brand]):
                p_b_tmp+=1
        if p_a_tmp>0:
            p_a+=1
        if p_b_tmp>0:
            p_b+=1
        if p_a_tmp >0 and p_b_tmp > 0:
            p_a_b+=1

        
    if p_a > 0 and p_b >0:
        return  (p_a_b / len(comments)) / ((p_a/len(comments)) * (p_b/len(comments)))
    else:
        return 0

# %%
# fixing the arguments comemnts and mis_brand_handle_t for function get_lift_value
comments = comments['comments']
get_lift_value_p = partial(get_lift_value, comments=comments, brand_models_map= brand_models_map)

# %%
# car_brands_org = car_brands.copy()
# car_brands = car_brands_org.copy()

# %%
# %%time
lift_values = []
for i_1, brand_1 in dict(list(enumerate(car_brands))).items():
    lift_value_tmp = []
    for i_2, brand_2 in dict(list(enumerate(car_brands))).items():
        if i_2 == i_1:
            lift_value_tmp.append(1)
        elif i_2 < i_1:
            lift_value_tmp.append(lift_values[i_2][i_1])
        else:
            lift_value_tmp.append(get_lift_value_p(brand_1, brand_2))
    lift_values.append(lift_value_tmp)
# Out:
# CPU times: total: 5min 13s
# Wall time: 5min 13s

# %%
lift_values = pd.DataFrame(lift_values, columns=car_brands, index=car_brands)
lift_values.to_csv('lift_values.csv')
